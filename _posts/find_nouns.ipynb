# %%
# import sys
# !{sys.executable} -m pip install nltk

import nltk

from nltk.corpus import brown
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem import SnowballStemmer
from nltk.stem import RegexpStemmer
from nltk.stem import RSLPStemmer
from nltk.stem import WordNetLemmatizer

def parse_book(book):
    # Tokenize the book
    tokens = word_tokenize(book)
    # Remove punctuation
    words = [word for word in tokens if word.isalpha()]
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]
    # Stemming
    porter = PorterStemmer()
    words = [porter.stem(word) for word in words]
    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    # POS Tagging
    tagged = nltk.pos_tag(words)
    # Find all nouns
    nouns = [word for word,pos in tagged if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS')]
    return nouns

def open_book(filename):
    with open(filename, 'r') as file:
        book = file.read()
    return book

def main():
    # Read the book
    book = open_book('romeo.txt')
    # Parse the book
    nouns = parse_book(book)
    # Print the nouns
    print(nouns)

main()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ['thi', 'prepar', 'pg', 'team', 'team', 'twenti', 'project', 'gutenberg', 'volunt', 'romeo', 'william', 'person', 'repres', 'verona', 'pari', 'kinsman', 'princ', 'head', 'varianc', 'man', 'capulet', 'romeo', 'son', 'montagu', 'mercutio', 'kinsman', 'princ', 'friend', 'romeo', 'benvolio', 'montagu', 'friend', 'romeo', 'tybalt', 'capulet', 'friar', 'friar', 'john', 'order', 'balthasar', 'servant', 'romeo', 'sampson', 'capulet', 'gregori', 'capulet', 'peter', 'nurs', 'montagu', 'apothecari', 'choru', 'page', 'page', 'ladi', 'montagu', 'wife', 'montagu', 'capulet', 'wife', 'capulet', 'daughter', 'capulet', 'nurs', 'verona', 'sever', 'men', 'woman', 'masker', 'guard', 'watchman', 'dure', 'part', 'play', 'verona', 'act', 'prologu', 'enter', 'chor', 'household', 'alik', 'digniti', 'lay', 'scene', 'grudg', 'mutini', 'blood', 'hand', 'loin', 'foe', 'pair', 'life', 'misadventur', 'piteou', 'death', 'buri', 'parent', 'fear', 'passag', 'love', 'parent', 'rage', 'end', 'naught', 'hour', 'traffic', 'stage', 'toil', 'mend', 'act', 'scene', 'place', 'enter', 'sampson', 'gregori', 'arm', 'sword', 'buckler', 'sampson', 'gregori', 'word', 'carri', 'coal', 'collier', 'sampson', 'choler', 'draw', 'draw', 'neck', 'sampson', 'i', 'strike', 'quickli', 'move', 'gregori', 'art', 'quickli', 'move', 'strike', 'dog', 'montagu', 'gregori', 'stir', 'stand', 'therefor', 'art', 'move', 'thou', 'dog', 'stand', 'i', 'wall', 'man', 'gregori', 'slave', 'goe', 'wall', 'sampson', 'woman', 'weaker', 'vessel', 'wall', 'therefor', 'i', 'men', 'thrust', 'maid', 'wall', 'quarrel', 'master', 'men', 'i', 'men', 'cruel', 'maid', 'i', 'head', 'head', 'head', 'thou', 'gregori', 'sen', 'stand', 'gregori', 'art', 'fish', 'thou', 'hadst', 'thou', 'hadst', 'draw', 'thi', 'tool', 'montagu', 'weapon', 'quarrel', 'i', 'turn', 'sampson', 'fear', 'marri', 'sampson', 'law', 'side', 'list', 'sampson', 'dare', 'i', 'disgrac', 'bear', 'enter', 'balthasar', 'abraham', 'sir', 'sampson', 'i', 'thumb', 'sir', 'abraham', 'sir', 'sampson', 'law', 'side', 'i', 'sampson', 'sir', 'sir', 'i', 'thumb', 'sir', 'gregori', 'quarrel', 'sir', 'sir', 'sampson', 'sir', 'i', 'man', 'sampson', 'gregori', 'master', 'kinsman', 'sampson', 'abraham', 'gregori', 'rememb', 'thi', 'benvolio', 'part', 'fool', 'sword', 'beat', 'enter', 'tybalt', 'art', 'drawn', 'hind', 'turn', 'benvolio', 'look', 'death', 'benvolio', 'i', 'peac', 'sword', 'part', 'men', 'drawn', 'talk', 'peac', 'i', 'word', 'hate', 'hell', 'montagu', 'thee', 'coward', 'join', 'fray', 'enter', 'citizen', 'club', 'citizen', 'club', 'bill', 'strike', 'montagu', 'enter', 'capulet', 'capulet', 'sword', 'ho', 'capulet', 'crutch', 'crutch', 'whi', 'call', 'sword', 'capulet', 'sword', 'i', 'montagu', 'come', 'blade', 'spite', 'enter', 'montagu', 'ladi', 'montagu', 'montagu', 'thou', 'capulet', 'let', 'montagu', 'thou', 'foot', 'seek', 'foe', 'enter', 'attend', 'princ', 'rebelli', 'enemi', 'peac', 'profan', 'steel', 'men', 'fire', 'pernici', 'rage', 'purpl', 'fountain', 'vein', 'pain', 'tortur', 'bloodi', 'hand', 'throw', 'mistemp', 'weapon', 'ground', 'sentenc', 'brawl', 'word', 'capulet', 'montagu', 'disturb', 'street', 'verona', 'cast', 'grave', 'ornament', 'hand', 'canker', 'part', 'canker', 'hate', 'forfeit', 'peac', 'time', 'afternoon', 'case', 'onc', 'death', 'men', 'exeunt', 'princ', 'capulet', 'capulet', 'tybalt', 'citizen', 'montagu', 'abroach', 'speak', 'nephew', 'adversari', 'fight', 'approach', 'i', 'part', 'instant', 'fieri', 'tybalt', 'sword', 'prepar', 'breath', 'defianc', 'head', 'cut', 'wind', 'interchang', 'blow', 'part', 'part', 'till', 'princ', 'part', 'part', 'ladi', 'montagu', 'o', 'romeo', 'glad', 'i', 'benvolio', 'hour', 'worshipp', 'sun', 'forth', 'window', 'troubl', 'mind', 'walk', 'grove', 'sycamor', 'side', 'walk', 'i', 'son', 'i', 'ware', 'wood', 'i', 'busi', 'alon', 'humour', 'pursu', 'gladli', 'shunn', 'gladli', 'mani', 'hath', 'morn', 'dew', 'ad', 'cloud', 'sigh', 'sun', 'begin', 'shadi', 'curtain', 'aurora', 'home', 'heavi', ...
